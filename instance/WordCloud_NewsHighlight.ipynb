# %%
import nltk
from nltk.corpus import stopwords
print(stopwords.words('english'))
# Out:
# ['i', 'me', 'my', 'myself', 'we', 'our', 'ours', 'ourselves', 'you', "you're", "you've", "you'll", "you'd", 'your', 'yours', 'yourself', 'yourselves', 'he', 'him', 'his', 'himself', 'she', "she's", 'her', 'hers', 'herself', 'it', "it's", 'its', 'itself', 'they', 'them', 'their', 'theirs', 'themselves', 'what', 'which', 'who', 'whom', 'this', 'that', "that'll", 'these', 'those', 'am', 'is', 'are', 'was', 'were', 'be', 'been', 'being', 'have', 'has', 'had', 'having', 'do', 'does', 'did', 'doing', 'a', 'an', 'the', 'and', 'but', 'if', 'or', 'because', 'as', 'until', 'while', 'of', 'at', 'by', 'for', 'with', 'about', 'against', 'between', 'into', 'through', 'during', 'before', 'after', 'above', 'below', 'to', 'from', 'up', 'down', 'in', 'out', 'on', 'off', 'over', 'under', 'again', 'further', 'then', 'once', 'here', 'there', 'when', 'where', 'why', 'how', 'all', 'any', 'both', 'each', 'few', 'more', 'most', 'other', 'some', 'such', 'no', 'nor', 'not', 'only', 'own', 'same', 'so', 'than', 'too', 'very', 's', 't', 'can', 'will', 'just', 'don', "don't", 'should', "should've", 'now', 'd', 'll', 'm', 'o', 're', 've', 'y', 'ain', 'aren', "aren't", 'couldn', "couldn't", 'didn', "didn't", 'doesn', "doesn't", 'hadn', "hadn't", 'hasn', "hasn't", 'haven', "haven't", 'isn', "isn't", 'ma', 'mightn', "mightn't", 'mustn', "mustn't", 'needn', "needn't", 'shan', "shan't", 'shouldn', "shouldn't", 'wasn', "wasn't", 'weren', "weren't", 'won', "won't", 'wouldn', "wouldn't"]

# %% [markdown]
# # get stopwords
# stop_words = set(stopwords.words('english'))
# stop_words

# %%
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
  
example_sent = "This is a sample sentence, showing off the stop words filtration."
  
stop_words = set(stopwords.words('english')) 
  
word_tokens = word_tokenize(example_sent) 
  
filtered_sentence = [w for w in word_tokens if not w in stop_words] 
  
filtered_sentence = [] 
  
for w in word_tokens: 
    if w not in stop_words: 
        filtered_sentence.append(w) 
  
print(word_tokens) 
print(filtered_sentence)
# Out:
# ['This', 'is', 'a', 'sample', 'sentence', ',', 'showing', 'off', 'the', 'stop', 'words', 'filtration', '.']
# ['This', 'sample', 'sentence', ',', 'showing', 'stop', 'words', 'filtration', '.']

# %%
from nltk.tokenize import word_tokenize  # to split sentences into words
from nltk.corpus import stopwords  # to get a list of stopwords
from collections import Counter  # to get words-frequency
import requests  # this we will use to call API and get data
import json  # to convert python dictionary to string format
import pandas as pd
import numpy as np
from newsapi.newsapi_client import NewsApiClient

# get API key from NewsAPI.org
NEWS_API_KEY= "112c9b2a21544785ac573f0221cff7ed"  # Jack

# %%
api = NewsApiClient(api_key=NEWS_API_KEY)        
# /v2/top-headlines
top_headlines = api.get_top_headlines(#q='bitcoin',
                                    #sources='bbc-news,the-verge',
                                    category='business',
                                    language='en',
                                    country='us',
                                    #from_param='2017-12-01',
                                    page_size = 70,
                                    page = 1
                                    )
print('status=', top_headlines['status'])
print('totalResults=', top_headlines['totalResults'])
result = pd.DataFrame(top_headlines['articles'])
result.replace(np.nan, "", inplace=True)
result.set_index(keys = ['publishedAt'], inplace=True)

sentences = ""
for news in result['title']:
    sentences = sentences + " " + news

sentences
# Out:
# status= ok
# totalResults= 70
# " 4 Virtually Flawless Stocks to Buy if the Market Crashes - Motley Fool Airlines’ New Pricing Strategy: Buy One, Get One Free - The Wall Street Journal Dutch government halts KLM bailout amid standoff over terms - Fox Business Exxon Mobil Should Be Accepted For What It Truly Is - Seeking Alpha Ask Amy: Plan to spend part of inheritance on personal item causes marital rift - OregonLive Elon Musk Declares Mars Exempt of Earthbound Laws: Colony Will Be Self-Governing - autoevolution People gather to watch Ohio State game, celebrate Halloween despite COVID-19 concerns - 10TV Delta Air Lines CFO Departing To Join General Motors - Simple Flying Satoshi Nakamoto's Bitcoin White Paper: A 12-Year Old Summary of Robust Unstructured Simplicity - Bitcoin News CDC: household COVID-19 transmission common, usually within 5 days - Business Insider - Business Insider Costco drops Chaokoh coconut milk allegations of forced monkey labor which sees the animals chained - Daily Mail Larimer County reports nearly 200 more COVID-19 cases Saturday - Loveland Reporter-Herald Trick-or-treating during COVID: 'Candypult' saves Halloween 2020 - New York Post  Tesla's updated Full Self-Driving beta needs fewer human interventions - Engadget Volunteer to receive 1st Israeli vaccine shot hails ‘historic opportunity’ - The Times of Israel Cruise ships can resume sailing in US waters -- but no passengers, yet - New York Post  Gas prices below $2: Coming to a gas station near you - CNN Half of New Orleans area's powerless buildings are in Jefferson Parish - NOLA.com Don't Feed The Bears: Here's What To Do Now - Investor's Business Daily 2022 GMC Hummer EV: See Inside, Out, and Underneath this new Electric Beast - The Fast Lane Ford Reveals Pricing Of Hands-Free Active Drive Assist System - Motor1  How Under Armour plans to compete after MyFitness deal, 'soul searching' on its brand - Yahoo Finance Netflix price hikes raise US cost of most popular plan by a dollar - CNET Black Friday Samsung TV deals 2020 - Tom's Guide Apple ordered to pay VirnetX $502.8 million in patent trial - The Verge Americans are moving out of dense, costly cities - Axios Amazon in dispute with partner in India - Seeking Alpha Tech earnings took a dark turn this week with warnings about the coronavirus and election - CNBC China Should Take Part in Creating Global Regulatory Framework for Digital Currency, Xi Says - CoinDesk Here's how much debt the average 20-something has—see how you compare - CNBC McRib lovers rejoice! McDonald's cult classic is coming back - KABC-TV Dunkin’ Brands to be bought by Inspire Brands for 11.3 billion - Boston.com How I Used Robinhood's Stock Trading Tools to Game the System - The Motley Fool Amazon drops French Black Friday ad campaign as lockdown starts - Reuters Baby Boomers and high earners now carry the most student loan debt: Fidelity study - The Philadelphia Inquirer Las Vegas MGM Resorts may partially close, CEO says - KHON2 34 spooky dessert recipes for this Halloween - msnNOW J&J plans to test its COVID-19 vaccine in ages 12-18 soon - Reuters Airbnb issues warning against Arizona house parties for Halloween weekend - AZFamily Forecast: 2021 US EV Sales To Increase 70% Year Over Year - CleanTechnica SBA presses big businesses to justify aid, sparking uproar - Politico Regeneron halts COVID-19 therapeutic trials on sick patients - One America News Network NICU babies in Texas celebrate their first Halloween dressed in handmade costumes - Daily Mail Twitter: Back In The Bargain Bin - Seeking Alpha It's Official: A Foreign Company Will Help Mitsubishi Build Japan's Next Fighter - The Drive Mayo Clinic Health System deferring elective procedures to care for COVID-19 surge - WEAU Some Georgians could run out of benefits next Monday - WTOC After NVIDIA and AMD, Marvell Technology Goes Shopping With $10 Billion Inphi Takeover - The Motley Fool Amazon Q3 Roundup: Analyst Sees Path For Stock To Hit $5K - Yahoo Finance Dozens of Applebee's and IHOP restaurants ...

# %%
# get stopwords
stop_words = set(stopwords.words('english'))
filteredtext = " ".join(list(stop_words))
#filteredtext
with open("filteredtext.txt", mode='w', encoding='utf-8') as f:
    f.write(filteredtext)
    f.closed

# %%
# split sentences into words
words = word_tokenize(sentences)

# get stopwords
stop_words = set(stopwords.words('english'))
    
# remove stopwords from our words list and also remove any word whose length is less than 3
# stopwords are commonly occuring words like is, am, are, they, some, etc.
words = [word for word in words if word not in stop_words and len(word) > 3]

# now, get the words and their frequency
words_freq = Counter(words)

#print(words_freq)

# JQCloud requires words in format {'text': 'sample', 'weight': '100'}
# so, lets convert out word_freq in the respective format
words_json = [{'text': word, 'weight': count} for word, count in words_freq.items()]
print(words_json)

# now convert it into a string format and return it
json.dumps(words_json)
# Out:
# [{'text': 'Virtually', 'weight': 1}, {'text': 'Flawless', 'weight': 1}, {'text': 'Stocks', 'weight': 1}, {'text': 'Market', 'weight': 1}, {'text': 'Crashes', 'weight': 1}, {'text': 'Motley', 'weight': 4}, {'text': 'Fool', 'weight': 4}, {'text': 'Airlines', 'weight': 1}, {'text': 'Pricing', 'weight': 2}, {'text': 'Strategy', 'weight': 1}, {'text': 'Free', 'weight': 1}, {'text': 'Wall', 'weight': 1}, {'text': 'Street', 'weight': 1}, {'text': 'Journal', 'weight': 1}, {'text': 'Dutch', 'weight': 1}, {'text': 'government', 'weight': 1}, {'text': 'halts', 'weight': 3}, {'text': 'bailout', 'weight': 1}, {'text': 'amid', 'weight': 1}, {'text': 'standoff', 'weight': 1}, {'text': 'terms', 'weight': 1}, {'text': 'Business', 'weight': 5}, {'text': 'Exxon', 'weight': 1}, {'text': 'Mobil', 'weight': 1}, {'text': 'Should', 'weight': 2}, {'text': 'Accepted', 'weight': 1}, {'text': 'What', 'weight': 2}, {'text': 'Truly', 'weight': 1}, {'text': 'Seeking', 'weight': 3}, {'text': 'Alpha', 'weight': 3}, {'text': 'Plan', 'weight': 1}, {'text': 'spend', 'weight': 1}, {'text': 'part', 'weight': 1}, {'text': 'inheritance', 'weight': 1}, {'text': 'personal', 'weight': 1}, {'text': 'item', 'weight': 1}, {'text': 'causes', 'weight': 1}, {'text': 'marital', 'weight': 1}, {'text': 'rift', 'weight': 1}, {'text': 'OregonLive', 'weight': 1}, {'text': 'Elon', 'weight': 1}, {'text': 'Musk', 'weight': 1}, {'text': 'Declares', 'weight': 1}, {'text': 'Mars', 'weight': 1}, {'text': 'Exempt', 'weight': 1}, {'text': 'Earthbound', 'weight': 1}, {'text': 'Laws', 'weight': 1}, {'text': 'Colony', 'weight': 1}, {'text': 'Will', 'weight': 2}, {'text': 'Self-Governing', 'weight': 1}, {'text': 'autoevolution', 'weight': 1}, {'text': 'People', 'weight': 1}, {'text': 'gather', 'weight': 1}, {'text': 'watch', 'weight': 1}, {'text': 'Ohio', 'weight': 1}, {'text': 'State', 'weight': 1}, {'text': 'game', 'weight': 1}, {'text': 'celebrate', 'weight': 2}, {'text': 'Halloween', 'weight': 5}, {'text': 'despite', 'weight': 1}, {'text': 'COVID-19', 'weight': 8}, {'text': 'concerns', 'weight': 1}, {'text': '10TV', 'weight': 1}, {'text': 'Delta', 'weight': 1}, {'text': 'Lines', 'weight': 1}, {'text': 'Departing', 'weight': 1}, {'text': 'Join', 'weight': 1}, {'text': 'General', 'weight': 1}, {'text': 'Motors', 'weight': 1}, {'text': 'Simple', 'weight': 1}, {'text': 'Flying', 'weight': 1}, {'text': 'Satoshi', 'weight': 1}, {'text': 'Nakamoto', 'weight': 1}, {'text': 'Bitcoin', 'weight': 3}, {'text': 'White', 'weight': 1}, {'text': 'Paper', 'weight': 1}, {'text': '12-Year', 'weight': 1}, {'text': 'Summary', 'weight': 1}, {'text': 'Robust', 'weight': 1}, {'text': 'Unstructured', 'weight': 1}, {'text': 'Simplicity', 'weight': 1}, {'text': 'News', 'weight': 6}, {'text': 'household', 'weight': 1}, {'text': 'transmission', 'weight': 1}, {'text': 'common', 'weight': 1}, {'text': 'usually', 'weight': 1}, {'text': 'within', 'weight': 1}, {'text': 'days', 'weight': 1}, {'text': 'Insider', 'weight': 2}, {'text': 'Costco', 'weight': 1}, {'text': 'drops', 'weight': 2}, {'text': 'Chaokoh', 'weight': 1}, {'text': 'coconut', 'weight': 1}, {'text': 'milk', 'weight': 1}, {'text': 'allegations', 'weight': 1}, {'text': 'forced', 'weight': 1}, {'text': 'monkey', 'weight': 1}, {'text': 'labor', 'weight': 1}, {'text': 'sees', 'weight': 2}, {'text': 'animals', 'weight': 1}, {'text': 'chained', 'weight': 1}, {'text': 'Daily', 'weight': 3}, {'text': 'Mail', 'weight': 2}, {'text': 'Larimer', 'weight': 1}, {'text': 'County', 'weight': 1}, {'text': 'reports', 'weight': 1}, {'text': 'nearly', 'weight': 1}, {'text': 'cases', 'weight': 2}, {'text': 'Saturday', 'weight': 1}, {'text': 'Loveland', 'weight': 1}, {'text': 'Reporter-Herald', 'weight': 1}, {'text': 'Trick-or-treating', 'weight': 1}, {'text': 'COVID', 'weight': 2}, {'text': "'Candypult", 'weight': 1}, {'text': 'saves', 'weight': 1}, {'text': '2020', 'weight': 4}, {'text': 'York', 'weight': 2}, {'text': 'Post', 'weight': 2}, {'text': 'Tesla', 'weight': 1}, {'text' ...
# '[{"text": "Virtually", "weight": 1}, {"text": "Flawless", "weight": 1}, {"text": "Stocks", "weight": 1}, {"text": "Market", "weight": 1}, {"text": "Crashes", "weight": 1}, {"text": "Motley", "weight": 4}, {"text": "Fool", "weight": 4}, {"text": "Airlines", "weight": 1}, {"text": "Pricing", "weight": 2}, {"text": "Strategy", "weight": 1}, {"text": "Free", "weight": 1}, {"text": "Wall", "weight": 1}, {"text": "Street", "weight": 1}, {"text": "Journal", "weight": 1}, {"text": "Dutch", "weight": 1}, {"text": "government", "weight": 1}, {"text": "halts", "weight": 3}, {"text": "bailout", "weight": 1}, {"text": "amid", "weight": 1}, {"text": "standoff", "weight": 1}, {"text": "terms", "weight": 1}, {"text": "Business", "weight": 5}, {"text": "Exxon", "weight": 1}, {"text": "Mobil", "weight": 1}, {"text": "Should", "weight": 2}, {"text": "Accepted", "weight": 1}, {"text": "What", "weight": 2}, {"text": "Truly", "weight": 1}, {"text": "Seeking", "weight": 3}, {"text": "Alpha", "weight": 3}, {"text": "Plan", "weight": 1}, {"text": "spend", "weight": 1}, {"text": "part", "weight": 1}, {"text": "inheritance", "weight": 1}, {"text": "personal", "weight": 1}, {"text": "item", "weight": 1}, {"text": "causes", "weight": 1}, {"text": "marital", "weight": 1}, {"text": "rift", "weight": 1}, {"text": "OregonLive", "weight": 1}, {"text": "Elon", "weight": 1}, {"text": "Musk", "weight": 1}, {"text": "Declares", "weight": 1}, {"text": "Mars", "weight": 1}, {"text": "Exempt", "weight": 1}, {"text": "Earthbound", "weight": 1}, {"text": "Laws", "weight": 1}, {"text": "Colony", "weight": 1}, {"text": "Will", "weight": 2}, {"text": "Self-Governing", "weight": 1}, {"text": "autoevolution", "weight": 1}, {"text": "People", "weight": 1}, {"text": "gather", "weight": 1}, {"text": "watch", "weight": 1}, {"text": "Ohio", "weight": 1}, {"text": "State", "weight": 1}, {"text": "game", "weight": 1}, {"text": "celebrate", "weight": 2}, {"text": "Halloween", "weight": 5}, {"text": "despite", "weight": 1}, {"text": "COVID-19", "weight": 8}, {"text": "concerns", "weight": 1}, {"text": "10TV", "weight": 1}, {"text": "Delta", "weight": 1}, {"text": "Lines", "weight": 1}, {"text": "Departing", "weight": 1}, {"text": "Join", "weight": 1}, {"text": "General", "weight": 1}, {"text": "Motors", "weight": 1}, {"text": "Simple", "weight": 1}, {"text": "Flying", "weight": 1}, {"text": "Satoshi", "weight": 1}, {"text": "Nakamoto", "weight": 1}, {"text": "Bitcoin", "weight": 3}, {"text": "White", "weight": 1}, {"text": "Paper", "weight": 1}, {"text": "12-Year", "weight": 1}, {"text": "Summary", "weight": 1}, {"text": "Robust", "weight": 1}, {"text": "Unstructured", "weight": 1}, {"text": "Simplicity", "weight": 1}, {"text": "News", "weight": 6}, {"text": "household", "weight": 1}, {"text": "transmission", "weight": 1}, {"text": "common", "weight": 1}, {"text": "usually", "weight": 1}, {"text": "within", "weight": 1}, {"text": "days", "weight": 1}, {"text": "Insider", "weight": 2}, {"text": "Costco", "weight": 1}, {"text": "drops", "weight": 2}, {"text": "Chaokoh", "weight": 1}, {"text": "coconut", "weight": 1}, {"text": "milk", "weight": 1}, {"text": "allegations", "weight": 1}, {"text": "forced", "weight": 1}, {"text": "monkey", "weight": 1}, {"text": "labor", "weight": 1}, {"text": "sees", "weight": 2}, {"text": "animals", "weight": 1}, {"text": "chained", "weight": 1}, {"text": "Daily", "weight": 3}, {"text": "Mail", "weight": 2}, {"text": "Larimer", "weight": 1}, {"text": "County", "weight": 1}, {"text": "reports", "weight": 1}, {"text": "nearly", "weight": 1}, {"text": "cases", "weight": 2}, {"text": "Saturday", "weight": 1}, {"text": "Loveland", "weight": 1}, {"text": "Reporter-Herald", "weight": 1}, {"text": "Trick-or-treating", "weight": 1}, {"text": "COVID", "weight": 2}, {"text": "\'Candypult", "weight": 1}, {"text": "saves", "weight": 1}, {"text": "2020", "weight": 4}, {"text": "York", "weight": 2}, {"text": "Post", "weight": 2}, {"text": "Tesla", "weight": 1}, {"tex ...

# %%
import io 
from nltk.corpus import stopwords 
from nltk.tokenize import word_tokenize 
#word_tokenize accepts a string as an input, not a file. 
stop_words = set(stopwords.words('english')) 
file1 = open("text.txt") 
line = file1.read()# Use this to read file content as a stream: 
words = line.split() 
for r in words: 
    if not r in stop_words: 
        appendFile = open('filteredtext.txt','a') 
        appendFile.write(" "+r) 
        appendFile.close()
# Out:
# ---------------------------------------------------------------------------
# FileNotFoundError                         Traceback (most recent call last)
# <ipython-input-7-e8bb9e9d6b64> in <module>
#       4 #word_tokenize accepts a string as an input, not a file.
#       5 stop_words = set(stopwords.words('english'))
# ----> 6 file1 = open("text.txt")
#       7 line = file1.read()# Use this to read file content as a stream:
#       8 words = line.split()
#
# FileNotFoundError: [Errno 2] No such file or directory: 'text.txt'
